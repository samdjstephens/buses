# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("bus_positions.csv")

# %%
df.head()
# Out:
#    t  bus  pos
# 0  1    1   76
# 1  1    2   21
# 2  2    1   77
# 3  2    2   22
# 4  3    1   78

# %%
# bus column is useless since each bus is recorded exactly once on each timestep
grpd = df.loc[:,['t', 'pos']].groupby('t')

# %%
def distance_between_buses(positions):
    positions = positions.values
    return min((positions[1] - positions[0]) % 182,
               (positions[0] - positions[1]) % 182)

# %%
grpd['pos'].agg(distance_between_buses)[:1000].plot(figsize=(10,10))
